# %%
mlflow server --host 127.0.0.1 --port 8080 --workers 1 --backend-store-uri .\mlruns --default-artifact-root .\mlruns

# %%
import random
import mlflow
from functools import partial
from itertools import starmap
from more_itertools import consume


# Define a function to log parameters and metrics
def log_run(run_name, test_no):
    with mlflow.start_run(run_name=run_name):
        mlflow.log_param("param1", random.choice(["a", "b", "c"]))
        mlflow.log_param("param2", random.choice(["d", "e", "f"]))
        mlflow.log_metric("metric1", random.uniform(0, 1))
        mlflow.log_metric("metric2", abs(random.gauss(5, 2.5)))


# Generate run names
def generate_run_names(test_no, num_runs=5):
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function
def execute_tuning(test_no):
    # Partial application of the log_run function
    log_current_run = partial(log_run, test_no=test_no)
    # Generate run names and apply log_current_run function to each run name
    runs = starmap(log_current_run, ((run_name,) for run_name in generate_run_names(test_no)))
    # Consume the iterator to execute the runs
    consume(runs)


# Set the tracking uri and experiment
mlflow.set_tracking_uri("http://localhost:8080")
mlflow.set_experiment("No Child Runs")

# Execute 5 hyperparameter tuning runs
consume(starmap(execute_tuning, ((x,) for x in range(5))))
# Out:
# 2026/03/23 17:36:40 INFO mlflow.tracking.fluent: Experiment with name 'No Child Runs' does not exist. Creating a new experiment.
# 🏃 View run run_0_test_0 at: http://localhost:8080/#/experiments/354980064662311364/runs/b46e754a94124ebcad69a54534fca801
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_1_test_0 at: http://localhost:8080/#/experiments/354980064662311364/runs/45fd60d7d5044e03bb74fbd05304103a
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_2_test_0 at: http://localhost:8080/#/experiments/354980064662311364/runs/6860b304c09742f09c6d8d72ec67aadc
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_3_test_0 at: http://localhost:8080/#/experiments/354980064662311364/runs/2851e0cdd6234398ac9ec2e111a60dcd
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_4_test_0 at: http://localhost:8080/#/experiments/354980064662311364/runs/f8beb69e07af46f08a88b5e3e8f0b8b4
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_0_test_1 at: http://localhost:8080/#/experiments/354980064662311364/runs/ca19387e579547e491972560090d8477
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_1_test_1 at: http://localhost:8080/#/experiments/354980064662311364/runs/ba5c87ce531c46f598428060ec76b18d
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_2_test_1 at: http://localhost:8080/#/experiments/354980064662311364/runs/d7faa5f3fc324427b5af057794d3ac5e
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_3_test_1 at: http://localhost:8080/#/experiments/354980064662311364/runs/630c9da01da44cd89e5707b982bb90aa
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_4_test_1 at: http://localhost:8080/#/experiments/354980064662311364/runs/e9a1ac5a91fa4369baadddabc777de6f
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_0_test_2 at: http://localhost:8080/#/experiments/354980064662311364/runs/9e70ba44f35f49b683ebf0a408989162
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_1_test_2 at: http://localhost:8080/#/experiments/354980064662311364/runs/bf3386e5e9684c30bddc282ca5eaa74b
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_2_test_2 at: http://localhost:8080/#/experiments/354980064662311364/runs/05955159493a4a9db2a4091b5524fa46
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_3_test_2 at: http://localhost:8080/#/experiments/354980064662311364/runs/6daf5437ec444bbaa4bbcd42061b3cb1
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_4_test_2 at: http://localhost:8080/#/experiments/354980064662311364/runs/ff79a511c4544c2c9db93530f570878a
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_0_test_3 at: http://localhost:8080/#/experiments/354980064662311364/runs/73110148448842269374d3ffe40ef5b9
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_1_test_3 at: http://localhost:8080/#/experiments/354980064662311364/runs/346148268d0a41e4a60b836b7acd77b5
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_2_test_3 at: http://localhost:8080/#/experiments/354980064662311364/runs/358b0288ab2f49e2ab5a39965e8a0dd3
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_3_test_3 at: http://localhost:8080/#/experiments/354980064662311364/runs/02df094c4e1842198b31abf57c4c0812
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_4_test_3 at: http://localhost:8080/#/experiments/354980064662311364/runs/cc72a500fd774e58bd01f80c652e786c
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_0_test_4 at: http://localhost:8080/#/experiments/354980064662311364/runs/3669cb7bfa044c378689eebcbc291467
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_1_test_4 at: http://localhost:8080/#/experiments/354980064662311364/runs/a511195f89224636868d431927597845
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_2_test_4 at: http://localhost:8080/#/experiments/354980064662311364/runs/878f45df0f7643ca9ac8269b47f422b4
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_3_test_4 at: http://localhost:8080/#/experiments/354980064662311364/runs/b65e3a558a4642288ed289fa1841b238
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364
# 🏃 View run run_4_test_4 at: http://localhost:8080/#/experiments/354980064662311364/runs/31393a79ee36498e8a073df5e41faefc
# 🧪 View experiment at: http://localhost:8080/#/experiments/354980064662311364

# %%
import random
import mlflow
from functools import partial
from itertools import starmap
from more_itertools import consume


# Define a function to log parameters and metrics and add tag
# logging for search_runs functionality
def log_run(run_name, test_no, param1_choices, param2_choices, tag_ident):
    with mlflow.start_run(run_name=run_name, nested=True):
        mlflow.log_param("param1", random.choice(param1_choices))
        mlflow.log_param("param2", random.choice(param2_choices))
        mlflow.log_metric("metric1", random.uniform(0, 1))
        mlflow.log_metric("metric2", abs(random.gauss(5, 2.5)))
        mlflow.set_tag("test_identifier", tag_ident)


# Generate run names
def generate_run_names(test_no, num_runs=5):
    return (f"run_{i}_test_{test_no}" for i in range(num_runs))


# Execute tuning function, allowing for param overrides,
# run_name disambiguation, and tagging support
def execute_tuning(
    test_no,
    param1_choices=["a", "b", "c"],
    param2_choices=["d", "e", "f"],
    test_identifier="",
):
    ident = "default" if not test_identifier else test_identifier
    # Use a parent run to encapsulate the child runs
    with mlflow.start_run(run_name=f"parent_run_test_{ident}_{test_no}"):
        # Partial application of the log_run function
        log_current_run = partial(
            log_run,
            test_no=test_no,
            param1_choices=param1_choices,
            param2_choices=param2_choices,
            tag_ident=ident,
        )
        mlflow.set_tag("test_identifier", ident)
        # Generate run names and apply log_current_run function to each run name
        runs = starmap(log_current_run, ((run_name,) for run_name in generate_run_names(test_no)))
        # Consume the iterator to execute the runs
        consume(runs)


# Set the tracking uri and experiment
mlflow.set_tracking_uri("http://localhost:8080")
mlflow.set_experiment("Nested Child Association")

# Define custom parameters
param_1_values = ["x", "y", "z"]
param_2_values = ["u", "v", "w"]

# Execute hyperparameter tuning runs with custom parameter choices
consume(starmap(execute_tuning, ((x, param_1_values, param_2_values) for x in range(5))))
# Out:
# 2026/03/23 18:01:57 INFO mlflow.tracking.fluent: Experiment with name 'Nested Child Association' does not exist. Creating a new experiment.
# 🏃 View run run_0_test_0 at: http://localhost:8080/#/experiments/102946472505439372/runs/c4604506834a4f96beec09ea9af6b026
# 🧪 View experiment at: http://localhost:8080/#/experiments/102946472505439372
# 🏃 View run run_1_test_0 at: http://localhost:8080/#/experiments/102946472505439372/runs/b27b12d46b6b417087229691d5f3512f
# 🧪 View experiment at: http://localhost:8080/#/experiments/102946472505439372
# 🏃 View run run_2_test_0 at: http://localhost:8080/#/experiments/102946472505439372/runs/ba796467fbe041cca0f177b728c1d378
# 🧪 View experiment at: http://localhost:8080/#/experiments/102946472505439372
# 🏃 View run run